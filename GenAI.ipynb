# %% [markdown]
# <a href="https://colab.research.google.com/github/hanumantha123456/17devstrom/blob/master/GenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
prompt = input("You: ").lower()   # normalize input once

if "hello" in prompt or "hi" in prompt:
    print("AI: Hello! Nice to meet you.")

elif "weather" in prompt:
    print("AI: I can’t check live weather, but hope it’s good outside.")

elif "time" in prompt:
    print("AI: I don’t have a clock, but it’s a great time to code.")

else:
    print("AI: Sorry, I don’t understand that yet.")
# Out:
# You: hh
# AI: Sorry, I don’t understand that yet.

# %%
import random

prompt = input("You: ").lower()

knowledge_base = {
    "capital_of_india": [
        "Delhi",
        "New Delhi",
        "The capital of India is New Delhi.",
        "New Delhi is the national capital of India, located on the banks of the Yamuna River."
    ],

    "software_development":[
        "Python",
        "Java",
        "Designing, building, testing, and maintaining applications using programming logic to solve real-world problems."

    ],

    " data_science": [
       "Linear algebra basics",
       "Understanding loss functions",
       "Extracting insights and building predictive models from data using statistics, algorithms, and computational techniques."
    ],
    "machine_learning":[
        "supervised learning",
        "unsupervised learning",
        "reinforcement learning",
        "Protecting systems, networks, and data from unauthorized access, attacks, and digital threats."
    ]
}


best_intent=None
highest_score=0



if "india" in prompt or "capital" in prompt:
    print("AI: Here is my response:")
    print(random.choice(knowledge_base["capital_of_india"]))

elif "software" in prompt or "development" in prompt:
    print("AI: Here is my response:")
    print(random.choice(knowledge_base["software_development"]))

elif "data" in prompt or "science" in prompt:
    print("AI: Here is my response:")
    print(random.choice(knowledge_base["data_science"]))

elif "machine" in prompt or "learning" in prompt:
    print("AI: Here is my response:")
    print(random.choice(knowledge_base["machine_learning"]))
elif "India" in prompt and "head quaters" in prompt:
    print("AI: The head quaters of India are New Delhi.")

else:
    print("AI: Sorry, I don’t understand that yet.")
# Out:
# You: India head quaters
# AI: Here is my response:
# Delhi
